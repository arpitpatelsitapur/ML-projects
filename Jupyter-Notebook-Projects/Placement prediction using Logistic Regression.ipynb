# %% [markdown]
# <h1 align='center'>Job placement prediction using Logistic Regression</h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../Datasets/Job_Placement_Data.csv")
df.head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# 0         Mkt&HR        58.80      Placed
# 1        Mkt&Fin        66.28      Placed
# 2        Mkt&Fin        57.80      Placed
# 3         Mkt&HR        59.43  Not Placed
# 4        Mkt&Fin        55.50      Placed

# %% [markdown]
# # 1 Preprocessing

# %%
df.shape
# Out:
# (215, 13)

# %%
df.isnull().sum()
# Out:
# gender                 0
# ssc_percentage         0
# ssc_board              0
# hsc_percentage         0
# hsc_board              0
# hsc_subject            0
# degree_percentage      0
# undergrad_degree       0
# work_experience        0
# emp_test_percentage    0
# specialisation         0
# mba_percent            0
# status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               215 non-null    object
#  1   ssc_percentage       215 non-null    float64
#  2   ssc_board            215 non-null    object
#  3   hsc_percentage       215 non-null    float64
#  4   hsc_board            215 non-null    object
#  5   hsc_subject          215 non-null    object
#  6   degree_percentage    215 non-null    float64
#  7   undergrad_degree     215 non-null    object
#  8   work_experience      215 non-null    object
#  9   emp_test_percentage  215 non-null    float64
#  10  specialisation       215 non-null    object
#  11  mba_percent          215 non-null    float64
#  12  status               215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
df['status']
# Out:
# 0          Placed
# 1          Placed
# 2          Placed
# 3      Not Placed
# 4          Placed
#           ...
# 210        Placed
# 211        Placed
# 212        Placed
# 213        Placed
# 214    Not Placed
# Name: status, Length: 215, dtype: object

# %%
df.describe()
# Out:
#        ssc_percentage  hsc_percentage  degree_percentage  emp_test_percentage  \
# count      215.000000      215.000000         215.000000           215.000000
# mean        67.303395       66.333163          66.370186            72.100558
# std         10.827205       10.897509           7.358743            13.275956
# min         40.890000       37.000000          50.000000            50.000000
# 25%         60.600000       60.900000          61.000000            60.000000
# 50%         67.000000       65.000000          66.000000            71.000000
# 75%         75.700000       73.000000          72.000000            83.500000
# max         89.400000       97.700000          91.000000            98.000000
#
#        mba_percent
# count   215.000000
# mean     62.278186
# std       5.833385
# min      51.210000
# 25%      57.945000
# 50%      62.000000
# 75%      66.255000
# max      77.890000

# %% [markdown]
# ## Plot a histogram of the ssc_percentage column

# %%
plt.hist(df['ssc_percentage'],bins=20)
plt.title("Distribution of SSC Percentage")
plt.xlabel('Percentage')
plt.ylabel('count')
plt.show()

# %%
plt.hist(df['gender'],bins=20)
plt.title("Distribution of Male & Female")
plt.xlabel('Gender')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Plot a scatterplot of ssc_percentage vs. hsc_percentage

# %%
sns.scatterplot(x='ssc_percentage',y='hsc_percentage',data=df,hue='status')
plt.title("Correlation bw SSC and HSC Percentage")
plt.show()

# %% [markdown]
# ## Plot a Boxenplot of ssc_percentage vs. hsc_percentage

# %%
sns.boxenplot(x='specialisation',y='degree_percentage',data=df)
plt.title('Difference in Degree Percentage by Specialisation')
plt.show()

# %% [markdown]
# ## categorical features into binary/dummy variables

# %%
df = pd.get_dummies(df,columns=['gender', 'ssc_board', 'hsc_board', 'hsc_subject', 'undergrad_degree', 'work_experience', 'specialisation', 'status'],drop_first=True)
df
# Out:
#      ssc_percentage  hsc_percentage  degree_percentage  emp_test_percentage  \
# 0             67.00           91.00              58.00                 55.0
# 1             79.33           78.33              77.48                 86.5
# 2             65.00           68.00              64.00                 75.0
# 3             56.00           52.00              52.00                 66.0
# 4             85.80           73.60              73.30                 96.8
# ..              ...             ...                ...                  ...
# 210           80.60           82.00              77.60                 91.0
# 211           58.00           60.00              72.00                 74.0
# 212           67.00           67.00              73.00                 59.0
# 213           74.00           66.00              58.00                 70.0
# 214           62.00           58.00              53.00                 89.0
#
#      mba_percent  gender_M  ssc_board_Others  hsc_board_Others  \
# 0          58.80      True              True              True
# 1          66.28      True             False              True
# 2          57.80      True             False             False
# 3          59.43      True             False             False
# 4          55.50      True             False             False
# ..           ...       ...               ...               ...
# 210        74.49      True              True              True
# 211        53.62      True              True              True
# 212        69.72      True              True              True
# 213        60.23     False              True              True
# 214        60.22      True             False              True
#
#      hsc_subject_Commerce  hsc_subject_Science  undergrad_degree_Others  \
# 0                    True                False                    False
# 1                   False                 True                    False
# 2                   False                False                    False
# 3                   False                 True                    False
# 4                    True                False                    False
# ..                    ...                  ...                      ...
# 210                  True                False                    False
# 211                 False                 True                    False
# 212                  True                False                    False
# 213                  True                False                    False
# 214                 False                 True                    False
#
#      undergrad_degree_Sci&Tech  work_experience_Yes  specialisation_Mkt&HR  \
# 0                         True                False                   True
# 1                         True                 True                  False
# 2                        False                False                  False
# 3                         True                False                   True
# 4                        False                False                  False
# ..                         ...                  ...                    ...
# 210                      False                False                  False
# 211                       True                False                  False
# 212                      False                 True                  False
# 213                      False                False                   True
# 214                      False                False                   True
#
#      status_Placed
# 0             True
# 1             True
# 2             True
# 3            False
# 4             True
# ..             ...
# 210           True
# 211           True
# 212           True
# 213           True
# 214          False
#
# [215 rows x 15 columns]

# %%
# relationship
corr = df.corr()
corr
# Out:
#                            ssc_percentage  hsc_percentage  degree_percentage  \
# ssc_percentage                   1.000000        0.511472           0.538404
# hsc_percentage                   0.511472        1.000000           0.434206
# degree_percentage                0.538404        0.434206           1.000000
# emp_test_percentage              0.261993        0.245113           0.224470
# mba_percent                      0.388478        0.354823           0.402364
# gender_M                        -0.068969       -0.021334          -0.173217
# ssc_board_Others                 0.116194       -0.137013           0.038070
# hsc_board_Others                 0.066996       -0.019548           0.067229
# hsc_subject_Commerce            -0.101323        0.258093          -0.022724
# hsc_subject_Science              0.189847       -0.226675           0.092006
# undergrad_degree_Others         -0.066127       -0.131382          -0.180408
# undergrad_degree_Sci&Tech        0.221235       -0.053599           0.123477
# work_experience_Yes              0.175675        0.141025           0.122648
# specialisation_Mkt&HR           -0.172536       -0.241630          -0.218286
# status_Placed                    0.607889        0.491228           0.479861
#
#                            emp_test_percentage  mba_percent  gender_M  \
# ssc_percentage                        0.261993     0.388478 -0.068969
# hsc_percentage                        0.245113     0.354823 -0.021334
# degree_percentage                     0.224470     0.402364 -0.173217
# emp_test_percentage                   1.000000     0.218055  0.084294
# mba_percent                           0.218055     1.000000 -0.300531
# gender_M                              0.084294    -0.300531  1.000000
# ssc_board_Others                     -0.018991     0.083120  0.019429
# hsc_board_Others                      0.039108     0.090201  0.065945
# hsc_subject_Commerce                 -0.021732    -0.049415 -0.001087
# hsc_subject_Science                   0.055352     0.048050  0.042682
# undergrad_degree_Others               0.006907    -0.036055 -0.093246
# undergrad_degree_Sci&Tech             0.009748     0.125009  0.084072
# work_experience_Yes                   0.056735     0.168811  0.085153
# specialisation_Mkt&HR                -0.236315    -0.105728 -0.106160
# status_Placed                         0.127639     0.076922  0.090670
#
#                            ssc_board_Others  hsc_board_Others  \
# ssc_percentage                     0.116194          0.066996
# hsc_percentage                    -0.137013         -0.019548
# degree_percentage                  0.038070          0.067229
# emp_test_percentage               -0.018991          0.039108
# mba_percent                        0.083120          0.090201
# gender_M                           0.019429          0.065945
# ssc_board_Others                   1.000000          0.605883
# hsc_board_Others                   0.605883          1.000000
# hsc_subject_Commerce              -0.056671         -0.073522
# hsc_subject_Science                0.058505          0.126446
# undergrad_degree_Others           -0.002758         -0.116920
# undergrad_degree_Sci&Tech          0.101060          0.086548
# work_experience_Yes               -0.040744          0.038357
# specialisation_Mkt&HR             -0.051565          0.002232
# status_Placed                      0.037297          0.016945
#
#                            hsc_subject_Commerce  hsc_subject_Science  \
# ssc_percentage                        -0.101323             0.189847
# hsc_percentage                         0.258093            -0.226675
# degree_percentage                     -0.022724             0.092006
# emp_test_percentage                   -0.021732             0.055352
# mba_percent                           -0.049415             0.048050
# gender_M                              -0.001087             0.042682
# ssc_board_Others                      -0.056671             0.058505
# hsc_board_Others                      -0.073522             0.126446
# hsc_subject_Commerce                   1.000000            -0.901673
# hsc_subject_Science                   -0.901673             1.000000
# undergrad_degree_Others               -0.202135             0.057432
# undergrad_degree_Sci&Tech             -0.584673             0.654593
# work_experience_Yes                   -0.056719             0.033270
# specialisation_Mkt&HR                 -0.129985             0.166639
# status_Placed                          0.024414             0.007279
#
#                            undergrad_degree_Others  undergrad_degree_Sci&Tech  \
# ssc_percentage                           -0.066127                   0.221235
# hsc_percentage                           -0.131382                  -0.053599
# degree_percentage                        -0.180408                   0.123477
# emp_test_percentage                       0.006907                   0.009748
# mba_percent                              -0.036055                   0.125009
# gender_M                                 -0.093246                   0.084072
# ssc_board_Others                         -0.002758                   0.101060
# hsc_board_Others                         -0.116920                   0.086548
# hsc_subject_Commerce                     -0.202135                  -0.584673
# hsc_subject_Science                       0.057432                   0.654593
# undergrad_degree_Others                   1.000000                  -0.142806
# undergrad_degree_Sci&Tech                -0.142806                   1.000000
# work_experience_Yes                       0.009507                   0.102962
# specialisation_Mkt&HR                     0.090948                   0.061503
# status_Placed                            -0.117232                   0.008688
#
#                            work_experience_Yes  specialisation_Mkt&HR  \
# ssc_percentage                        0.175675              -0.172536
# hsc_percentage                        0.141025              -0.241630
# degree_percentage                     0.122648              -0.218286
# emp_test_percentage                   0.056735              -0.236315
# mba_percent                           0.168811              -0.105728
# gender_M                              0.085153              -0.106160
# ssc_board_Others                     -0.040744              -0.051565
# hsc_board_Others                      0.038357               0.002232
# hsc_subject_Commerce                 -0.056719              -0.129985
# hsc_subject_Science                   0.033270               0.166639
# undergrad_degree_Others               0.009507               0.090948
# undergrad_degree_Sci&Tech             0.102962               0.061503
# work_experience_Yes                   1.000000              -0.191174
# specialisation_Mkt&HR                -0.191174               1.000000
# status_Placed                         0.276060              -0.250655
#
#                            status_Placed
# ssc_percentage                  0.607889
# hsc_percentage                  0.491228
# degree_percentage               0.479861
# emp_test_percentage             0.127639
# mba_percent                     0.076922
# gender_M                        0.090670
# ssc_board_Others                0.037297
# hsc_board_Others                0.016945
# hsc_subject_Commerce            0.024414
# hsc_subject_Science             0.007279
# undergrad_degree_Others        -0.117232
# undergrad_degree_Sci&Tech       0.008688
# work_experience_Yes             0.276060
# specialisation_Mkt&HR          -0.250655
# status_Placed                   1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,cmap='plasma',annot=True,fmt=".2f")
plt.show()

# %% [markdown]
# # Train Test Split

# %%
x = df.drop('status_Placed',axis=1)
y = df['status_Placed']

# %%
print(x.shape,'\n\n',y.shape)
# Out:
# (215, 14)
#
#  (215,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
print(X_train.shape,'\n\n',X_test.shape)
# Out:
# (172, 14)
#
#  (43, 14)

# %% [markdown]
# # Train Logistic Model

# %%
lg = LogisticRegression()
lg.fit(X_train,y_train)
y_pred = lg.predict(X_test)

# %% [markdown]
# # comparison between outputs

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.813953488372093

# %%
df.sample(5)
# Out:
#      ssc_percentage  hsc_percentage  degree_percentage  emp_test_percentage  \
# 158            67.0            63.0              64.00                60.00
# 188            61.8            47.0              54.38                57.00
# 192            65.2            61.4              64.80                93.40
# 97             70.5            62.5              61.00                93.91
# 100            45.0            57.0              58.00                56.39
#
#      mba_percent  gender_M  ssc_board_Others  hsc_board_Others  \
# 158        61.87      True              True              True
# 188        56.13      True              True              True
# 192        57.34      True             False             False
# 97         69.03     False             False              True
# 100        64.95     False              True              True
#
#      hsc_subject_Commerce  hsc_subject_Science  undergrad_degree_Others  \
# 158                 False                 True                    False
# 188                  True                False                    False
# 192                  True                False                    False
# 97                   True                False                    False
# 100                  True                False                    False
#
#      undergrad_degree_Sci&Tech  work_experience_Yes  specialisation_Mkt&HR  \
# 158                       True                False                  False
# 188                      False                False                  False
# 192                      False                 True                  False
# 97                       False                False                  False
# 100                      False                 True                   True
#
#      status_Placed
# 158          False
# 188          False
# 192           True
# 97           False
# 100          False

# %% [markdown]
# # Prediction System

# %%
input_data = (67.0,70.0,65.0,88.00,71.96,0,0,0,1,0,1,0,0,1)

np_df = np.asarray(input_data)
reshaped_df = np_df.reshape(1,-1)
pred = lg.predict(reshaped_df)
if pred[0] == 1:
    print("this person is placed for the job")
else:
    print("this person is not placed for the job")
# Out:
# this person is not placed for the job
